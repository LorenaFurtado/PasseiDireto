# %% [markdown]
#    #                              Desafio Passei Direto - Lorena Bernardo Vianna
#
#
# Este código está dividido em XXXX partes:
# 1ª) Importação das bibliotecas/ pacotes necessários para a leitura dos arquivos e construção de análises
# 2ª) Leitura de cada arquivo

# %%
# Importando as bibliotecas necessárias:
import json 
import pandas as pd 
from pandas.io.json import json_normalize #pacote para transformar .json em dataframe
import matplotlib.pyplot as plt
import numpy as np 
import pylab # importante para redefinição dos tamanhos dos gráficos

# %%
# Lendo os arquivos enviados:
with open(r'C:\Users\loren\Downloads\Passei Direto\friend_connection.json') as f:
    d = json.load(f)

friend_connection = json_normalize(d['friend_connection'])
friend_connection.head(3)
# Out:
#   Client FriendRequestId                    FriendshipHash        Id  \
# 0               29319610  f9957c00b31a8df6fdf4d0649e2a1851  40158628
# 1               29319610  f9957c00b31a8df6fdf4d0649e2a1851  40158627
# 2                 811349  fab14c01cd70332200c096637928e3f7  40158624
#
#   Student1Id Student2Id
# 0   16474100   16982798
# 1   16982798   16474100
# 2     831469     835427

# %%
#df = pd.DataFrame(data)
#df.head(3)
friend_connection.columns
# Out:
# Index(['Client', 'FriendRequestId', 'FriendshipHash', 'Id', 'Student1Id',
#        'Student2Id'],
#       dtype='object')

# %%
# verificando o que pode ser o conteúdo da base:
# pegando o primeiro FriendRequestId e verificando quantas vezes se repete
friend_connection[friend_connection['FriendRequestId'] =='29319610']
# Out:
#   Client FriendRequestId                    FriendshipHash        Id  \
# 0               29319610  f9957c00b31a8df6fdf4d0649e2a1851  40158628
# 1               29319610  f9957c00b31a8df6fdf4d0649e2a1851  40158627
#
#   Student1Id Student2Id
# 0   16474100   16982798
# 1   16982798   16474100

# %%
friend_connection[friend_connection['Id'] =='40158628']
# Out:
#   Client FriendRequestId                    FriendshipHash        Id  \
# 0               29319610  f9957c00b31a8df6fdf4d0649e2a1851  40158628
#
#   Student1Id Student2Id
# 0   16474100   16982798

# %% [markdown]
# ____________________________________________________________________________________________________________
#
# Não foi possível identificar o que representa esta base de friend_connection.
# ____________________________________________________________________________________________________________

# %%
# Lendo os arquivos enviados:
with open(r'C:\Users\loren\Downloads\Passei Direto\friend_request.json') as f:
    d = json.load(f)

friend_request = json_normalize(d['friendrequest'])
friend_request.head(3)
# Out:
#   AcceptanceDate   Client                    FriendshipHash        Id Message  \
# 0                 Website  aea4f6a172ab870e7a12b1cdfb0fae69  29320589
# 1                 Website  6989cabea5b68101188b6a759b089997  29320588
# 2                 Website  8437199e809d390387d220c23a5d5379  29320587
#
#   ReceiverId          RequestDate SenderId Status
# 0    2072809  2015-12-07 19:32:46  6129347      P
# 1    4102331  2015-12-07 19:32:41  6129347      P
# 2    2145928  2015-12-07 19:32:40  6129347      P

# %%
# Lendo os arquivos enviados:
with open(r'C:\Users\loren\Downloads\Passei Direto\student_aggregate.json') as f:
    d = json.load(f)

student_aggregate = json_normalize(d['student_aggregate'])
student_aggregate.head(10)
# Out:
#   Active CityId   Client CourseMapId                           CourseName  \
# 0   true   2116  Website     1199559  Engenharia Florestal e Silvicultura
# 1   true   2358  Website     1199555                  Engenharia Elétrica
# 5      94       664166  Faculdade de Administração, Ciências, Educação...
# 6      91      1614530                       Centro Universitário UNINTER
# 7     101       662762                Universidade Estadual de Santa Cruz
# 8      84       665611           Centro Universitário do Distrito Federal
# 9      98       664491          Instituto Pernambucano de Ensino Superior
#
#   UploadCount        cityName            stateName
# 0           0         Mossoró  Rio Grande do Norte
# 1           0          Recife           Pernambuco
# 2           0  Belo Horizonte         Minas Gerais
# 3           0       São Paulo            São Paulo
# 4           0        Botucatu            São Paulo
# 5           0        Curitiba               Paraná
# 6           0        Gravataí    Rio Grande do Sul
# 7           0          Ilhéus                Bahia
# 8           0        Brasília     Distrito Federal
# 9           0          Recife           Pernambuco

# %%
# verificando o mesmo Id da base de friend_connection se aparece nesta base:
student_aggregate[student_aggregate['Id'] =='40158628']
# Out:
# Empty DataFrame
# Columns: [Active, CityId, Client, CourseMapId, CourseName, Email, FirstAccessedPage, Fullname, Gender, Id, IsMobileRegister, LastLoginDate, RegisteredDate, StateId, UniversityId, UniversityName, UploadCount, cityName, stateName]
# Index: []

# %%
# verificando o mesmo Student1Id da base de friend_connection se aparece nesta base:
student_aggregate[student_aggregate['Id'] =='16474100']
# Out:
# Empty DataFrame
# Columns: [Active, CityId, Client, CourseMapId, CourseName, Email, FirstAccessedPage, Fullname, Gender, Id, IsMobileRegister, LastLoginDate, RegisteredDate, StateId, UniversityId, UniversityName, UploadCount, cityName, stateName]
# Index: []

# %%
# verificando o mesmo FriendrequestId da base de friend_connection se aparece nesta base:
student_aggregate[student_aggregate['Id'] =='29319610']
# Out:
# Empty DataFrame
# Columns: [Active, CityId, Client, CourseMapId, CourseName, Email, FirstAccessedPage, Fullname, Gender, Id, IsMobileRegister, LastLoginDate, RegisteredDate, StateId, UniversityId, UniversityName, UploadCount, cityName, stateName]
# Index: []

# %%
# fazendo join entre a tabela student_answer e student_aggregate pela chave Id:
result = pd.merge(friend_request, student_aggregate, on='Id')
result
# Out:
# Empty DataFrame
# Columns: [AcceptanceDate, Client_x, FriendshipHash, Id, Message, ReceiverId, RequestDate, SenderId, Status, Active, CityId, Client_y, CourseMapId, CourseName, Email, FirstAccessedPage, Fullname, Gender, IsMobileRegister, LastLoginDate, RegisteredDate, StateId, UniversityId, UniversityName, UploadCount, cityName, stateName, Genero]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ____________________________________________________________________________________________________________
#
# Com os comandos acima, tentei verificar se alguns dos Ids da base friend_connection apareciam na base student_aggregate
# para tentar identificar o conteúdo das bases, mas como nenhum dos Ids da base de friend_connection  testado não aparece na
# base de student_aggregate que aparenta ser uma base com os dados agregados dos cadastrados, não é possível saber o conteúdo
# da base de friend_connection. e muito menos realizar inferências entre quantidade de amigos e estado, curso, etc.
# ____________________________________________________________________________________________________________

# %%
student_aggregate.RegisteredDate.min()
# Out:
# '2015-12-07 12:57:54'

# %%
student_aggregate.RegisteredDate.max()
# Out:
# '2015-12-07 16:47:36'

# %%
student_aggregate.LastLoginDate.min()
# Out:
# '2015-12-07 12:57:53'

# %%
student_aggregate.LastLoginDate.max()
# Out:
# '2015-12-07 16:47:36'

# %% [markdown]
# _____________________________________________________________________________________________________________________
#
# Ou a base acima é uma foto dos registros realizados no dia 07 de dezembro de 2015, ou os campos de data estão com erro.
#
# _____________________________________________________________________________________________________________________

# %%
student_aggregate.groupby(u'Gender')[u'Fullname'].value_counts()
# Out:
# Gender  Fullname
# false   Aline Ferreira                    1
#         Aline Licen                       1
#         Aline Naue                        1
#         Alrac Ana                         1
#         Amanda Coury                      1
#         Amanda Lamarca Dela Plata         1
#         Amanda Monteiro Elias             1
#         Ana Clara Paz                     1
#         Ana Marii                         1
#         Ana Paula Moreto                  1
#         Ana PaulaT. Borges                1
#         Ana Thereza Carvalho              1
#         Ana Valeria                       1
#         AnaRita Ablas                     1
#         Angela Pracz                      1
#         Aparecida Torrecillas             1
#         Arianne Samira Alves              1
#         Belisa Gaudereto                  1
#         Bianca Felipe                     1
#         Bianca Guedes                     1
#         Bruna Ferreira                    1
#         Bruna Lanzillotta                 1
#         Bruna Oliveiira                   1
#         Bruna Teixeira                    1
#         Bárbara Salvan                    1
#         Carla Tardelli Soares             1
#         Chris Paulino                     1
#         Cintia Loureiro                   1
#         Cintia Tusset                     1
#         Claudete Lares                    1
#                                          ..
# true    Rodrigo Felix                     1
#         Rodrigo Moraes                    1
#         Rodrigo Pinto Coelho              1
#         Romário Teclas                    1
#         Rossirlez Rodrigues da Silva      1
#         Rômulo Diogo                      1
#         Sergio Alves                      1
#         Sergio Moreira da Costa           1
#         SilasValeria Avila                1
#         Thiago Corrêa                     1
#         Thiago Porto                      1
#         Thiago Yamada                     1
#         Tiago Mota                        1
#         Tiago Vasques                     1
#         Victor Giovanne                   1
#         Victor Weindenfeler               1
#         Vinicius Bazani                   1
#         Vinícius Rafael Q. Silva          1
#         Vinícius Silva                    1
#         Vitor Lopes                       1
#         Wagner Filho                      1
#         Wallyson Oliveira                 1
#         Walter Gustavo                    1
#         WanderCleber Pereira              1
#         Willy Oliveira                    1
#         WilsonNeto Prointest              1
#         Windy Brito                       1
#         Yohel Domingo Larrauri Pizarro    1
#         Yúri Vaz                          1
#         ÂngeloR. Pucci Vogel              1
# Name: Fullname, Length: 300, dtype: int64

# %%
# Com o resultado acima, supõe-se que Gender=True é sexo Masculino e Gender=False é sexo feminino
student_aggregate['Genero'] = '0'

for b in student_aggregate.itertuples():
    if b.Gender.find("false") != -1: 
        student_aggregate.Genero[b.Index] = 'Feminino' 
    if b.Gender.find("true") !=-1: 
        student_aggregate.Genero[b.Index] = 'Masculino'
   
student_aggregate.groupby('Genero').count().Id
# Out:
# Genero
# Feminino     148
# Masculino    152
# Name: Id, dtype: int64

# %%
# definindo o tamanho do gráfico
pylab.rcParams['figure.figsize'] = (4.0, 4.0)

segmentos = student_aggregate['Genero'].value_counts().index    

values = student_aggregate['Genero'].value_counts()

cores = ['lightgreen', 'lightblue']    

#explode = (0.1, 0, 0, 0)  # somente explode primeiro pedaço 

total = sum(values)

plt.pie(values, labels=segmentos, colors=cores, autopct='%1.1f%%', shadow=False, startangle=90)
#autopct='%1.1f%%' coloca os as quantidades em %
#plt.axis('equal')
#plt.title('Distribuição por Gênero')

plt.show()

# %%
# definindo o tamanho do gráfico
pylab.rcParams['figure.figsize'] = (8.0, 8.0)
fig, ax = plt.subplots()
y_pos = np.arange(len(student_aggregate['CourseName'].value_counts().head(20)))
values = student_aggregate['CourseName'].value_counts().head(20)
segmentos = student_aggregate['CourseName'].value_counts().head(20).index #é necessário colocar esse .index para que os segmentos sejam na mesma ordem 
ax.barh(y_pos, values, align='center', color='gray')
ax.set_yticks(y_pos)
ax.set_yticklabels(segmentos)
ax.invert_yaxis()
#ax.set_xlabel('Qtd de estudantes')
#ax.set_title('Os 20 cursos que mais possuem estudantes cadastrados')
plt.show()

# %%
contagem = student_aggregate[['CourseName','Id']].groupby(['CourseName'])['Id'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=True) \
                             .head(40)

print (contagem)
# Out:
#                                        CourseName  count
# 45                          Engenharia de Energia      1
# 80                          Redes de Computadores      1
# 56                 Gestão de Processos Gerenciais      1
# 79                                     Radiologia      1
# 28                         Eletricidade e Energia      1
# 55                            Gestão da Segurança      1
# 30                         Engenharia Aeronáutica      1
# 54                  Gestão da Produção Industrial      1
# 53                           Gestão da Informação      1
# 33    Engenharia Ambiental e Energias Renováveis       1
# 34                           Engenharia Biomédica      1
# 35                      Engenharia Biotecnológica      1
# 71                            Matemática Aplicada      1
# 38            Engenharia Florestal e Silvicultura      1
# 39                           Engenharia Geológica      1
# 77                                 Psicopedagogia      1
# 41                         Engenharia Metalúrgica      1
# 86                         Tecnologia Mecatrônica      1
# 88         Tecnologia da Informação e Comunicação      1
# 81                        Relações Internacionais      1
# 22                    Design - Desenho Industrial      1
# 19  Comunicação Social - Publicidade e Propaganda      1
# 70                                     Matemática      1
# 3                             Antropologia Social      1
# 68                        Licenciatura em Química      1
# 67                    Licenciatura em Informática      1
# 66                       Licenciatura em História      1
# 7                                           Artes      1
# 64                      Licenciatura em Filosofia      1
# 20         Comunicação Social - Rádio e Televisão      1
# 11                                  Biotecnologia      1
# 82                              Segurança Pública      1
# 89                   Tecnologia em Eletrotécnica       1
# 14                              Ciências Naturais      1
# 60        Letras e Línguas - Estudos Linguísticos      1
# 59                                Lazer e Turismo      1
# 18        Comunicação Social - Produção Editorial      1
# 12            Cinema de Animação e Artes Digitais      1
# 90                                        Turismo      1
# 63                     Licenciatura em Enfermagem      2

# %%
# definindo o tamanho do gráfico
pylab.rcParams['figure.figsize'] = (8.0, 8.0)
fig, ax = plt.subplots()
y_pos = np.arange(len(student_aggregate['UniversityName'].value_counts().head(20)))
values = student_aggregate['UniversityName'].value_counts().head(20)
segmentos = student_aggregate['UniversityName'].value_counts().head(20).index #é necessário colocar esse .index para que os segmentos sejam na mesma ordem 
ax.barh(y_pos, values, align='center', color='gray')
ax.set_yticks(y_pos)
ax.set_yticklabels(segmentos)
ax.invert_yaxis()
#ax.set_xlabel('Qtd de estudantes')
#ax.set_title('Os 20 Universidades que mais possuem estudantes cadastrados')
plt.show()

# %%
aux=student_aggregate[(student_aggregate['UniversityName']=='Universidade Estácio de Sá')
                     | (student_aggregate['UniversityName']=='Universidade Estácio de Sá - EAD')
                     | (student_aggregate['UniversityName']=='Universidade Paulista')]

# definindo o tamanho do gráfico
pylab.rcParams['figure.figsize'] = (4.0, 4.0)

segmentos = aux['Genero'].value_counts().index    

values = aux['Genero'].value_counts()

cores = ['lightgreen', 'lightblue']    

#explode = (0.1, 0, 0, 0)  # somente explode primeiro pedaço 

total = sum(values)

plt.pie(values, labels=segmentos, colors=cores, autopct='%1.1f%%', shadow=False, startangle=90)
#autopct='%1.1f%%' coloca os as quantidades em %
#plt.axis('equal')
#plt.title('Distribuição por Gênero')

plt.show()

# %%
student_aggregate.groupby('stateName').count().Id
# Out:
# stateName
# Acre                    1
# Alagoas                 5
# Amazonas                4
# Bahia                   6
# Ceara                  13
# Distrito Federal        8
# Espirito Santo          3
# Goias                  11
# Maranhão                4
# Mato Grosso             4
# Mato Grosso do Sul      2
# Minas Gerais           38
# Paraná                 16
# Paraíba                 4
# Pará                    4
# Pernambuco             17
# Piauí                   2
# Rio Grande do Norte     7
# Rio Grande do Sul      15
# Rio de Janeiro         53
# Rondonia                1
# Santa Catarina         10
# Sergipe                 4
# São Paulo              67
# Tocantins               1
# Name: Id, dtype: int64

# %%
# definindo o tamanho do gráfico
pylab.rcParams['figure.figsize'] = (8.0, 8.0)
fig, ax = plt.subplots()
#definindo o eixo y:
y_pos = np.arange(len(student_aggregate['stateName'].value_counts()))
#definindo o "tamanho" das barras:
values = student_aggregate['stateName'].value_counts()
# definindo os labels do eixo y:
segmentos = student_aggregate['stateName'].value_counts().index #é necessário colocar esse .index para que os segmentos sejam na mesma ordem 
#plotando o gráfico:
ax.barh(y_pos, values, align='center', color='gray')
ax.set_yticks(y_pos)
ax.set_yticklabels(segmentos)
ax.invert_yaxis() # para colocar em ordem decrescente
#ax.set_xlabel('') #descrição do eixo x
#ax.set_title('Número de Estudantes Inscritos por Estado') #título
plt.show()

# %% [markdown]
# ___________________________________________________________________________________
#
# A maior concentração de usuários está na região Sudeste.
# ___________________________________________________________________________________

# %%
aux=student_aggregate[(student_aggregate['stateName']=='São Paulo')
                     | (student_aggregate['stateName']=='Rio de Janeiro')
                     | (student_aggregate['stateName']=='Minas Gerais')]

# definindo o tamanho do gráfico
pylab.rcParams['figure.figsize'] = (4.0, 4.0)

segmentos = aux['Genero'].value_counts().index    

values = aux['Genero'].value_counts()

cores = ['lightgreen', 'lightblue']    

#explode = (0.1, 0, 0, 0)  # somente explode primeiro pedaço 

total = sum(values)

plt.pie(values, labels=segmentos, colors=cores, autopct='%1.1f%%', shadow=False, startangle=90)
#autopct='%1.1f%%' coloca os as quantidades em %
#plt.axis('equal')
#plt.title('Distribuição por Gênero')

plt.show()

# %%
student_aggregate.groupby('IsMobileRegister').count().Id
# Out:
# IsMobileRegister
# false    298
# true       2
# Name: Id, dtype: int64

# %% [markdown]
# ___________________________________________________________________________________
#
# Há pouquíssimos usuários com registro feito através de terminal móvel.
# ___________________________________________________________________________________

# %%
# Lendo os arquivos enviados:
with open(r'C:\Users\loren\Downloads\Passei Direto\student_answer.json', encoding="utf8") as f:
    d = json.load(f)

student_answer = json_normalize(d['student_answer'])
student_answer.head(3)
# Out:
#   Active AnswerClient   AnswerCreationDate  AnswerId AnswerQuestionId  \
# 0   true               2015-12-07 15:18:02  17763294          5074174
# 1   true               2015-12-07 15:03:11  17762984         17762377
# 2   true               2015-12-07 14:47:01  17762678         17580522
#
#     Client                           Email  \
# 0  Website       murillomoraes08@gmail.com
# 1  Website    barbara.balooalves@gmail.com
# 2  Website  beatriz2015direito@outlook.com
#
#                                    FirstAccessedPage              Fullname  \
# 0                      https://www.passeidireto.com/  MurilloArcuri Moraes
# 1  https://www.passeidireto.com/arquivo/4197285/l...               Bárbara
# 2  https://www.passeidireto.com/arquivo/10987443/...        BEATRIZEDUARDA
#
#   Gender        Id IsMobileRegister        LastLoginDate       RegisteredDate  \
# 0  false  17762776            false  2015-12-07 15:22:28  2015-12-07 14:51:32
# 1  false  17762682            false  2015-12-07 14:47:04  2015-12-07 14:47:03
# 2  false  17762395            false  2015-12-07 14:33:32  2015-12-07 14:33:32
#
#   UploadCount
# 0           0
# 1           0
# 2           0

# %%
# verificando se Ids desta base(student_answer) aparecem na base de dados dos estudantes:
student_aggregate[(student_aggregate['Id'] =='17762776') 
                      | (student_aggregate['Id'] =='17762682') 
                      | (student_aggregate['Id'] == '17762395') ]
# Out:
# Empty DataFrame
# Columns: [Active, CityId, Client, CourseMapId, CourseName, Email, FirstAccessedPage, Fullname, Gender, Id, IsMobileRegister, LastLoginDate, RegisteredDate, StateId, UniversityId, UniversityName, UploadCount, cityName, stateName, Genero]
# Index: []

# %%
# fazendo join entre a tabela student_answer e student_aggregate pela chave Id:
result = pd.merge(student_answer, student_aggregate, on='Id')
result
# Out:
#   Active_x AnswerClient   AnswerCreationDate  AnswerId AnswerQuestionId  \
# 0     true               2015-12-07 13:50:25  17761647         17720688
# 1     true               2015-12-07 13:51:06  17761650         17720688
# 2     true               2015-12-07 13:45:40  17761573          6695391
#
#   Client_x                Email_x  \
# 0  Website   lais.ane@hotmail.com
# 1  Website   lais.ane@hotmail.com
# 2  Website  ligialanna@uol.com.br
#
#                                  FirstAccessedPage_x          Fullname_x  \
# 0  https://www.passeidireto.com/arquivo/17450205/...         Lais Garcia
# 1  https://www.passeidireto.com/arquivo/17450205/...         Lais Garcia
# 2                                                     Ligia Lanna Dantas
#
#   Gender_x    ...    IsMobileRegister_y      LastLoginDate_y  \
# 0    false    ...                 false  2015-12-07 13:41:45
# 1    false    ...                 false  2015-12-07 13:41:45
# 2    false    ...                 false  2015-12-07 13:18:42
#
#       RegisteredDate_y StateId UniversityId  \
# 0  2015-12-07 13:41:42     106      1614530
# 1  2015-12-07 13:41:42     106      1614530
# 2  2015-12-07 13:18:41      82       665148
#
#                        UniversityName UploadCount_y        cityName  \
# 0        Centro Universitário UNINTER             0        Campinas
# 1        Centro Universitário UNINTER             0        Campinas
# 2  Centro Universitário Augusto Motta             0  Rio de Janeiro
#
#         stateName    Genero
# 0       São Paulo  Feminino
# 1       São Paulo  Feminino
# 2  Rio de Janeiro  Feminino
#
# [3 rows x 34 columns]

# %% [markdown]
# ________________________________________________________________________________________________________
#
# Como foi econtrado somente 3 Ids no join entre as tabelas tudent_answer e student_aggregate, não é possível
# realizar inferências sobre quais cursos são os que mais respondem, ou quais são os estados mais participativos.
#
# ________________________________________________________________________________________________________

# %%
# Lendo os arquivos enviados:
with open(r'C:\Users\loren\Downloads\Passei Direto\student_comment.json', encoding="utf8") as f:
    d = json.load(f)

student_comment = json_normalize(d['student_comment'])
student_comment.head(3)
# Out:
#   Active                    Client             CommentClient  \
# 0   true  Android | 5.0.2 | sdk 21  Android | 5.0.2 | sdk 21
# 1   true                   Website
# 2   true                   Website
#
#   CommentContentObjectId CommentID   CommentPublishDate  \
# 0                2384923  17763931  2015-12-07 15:50:20
# 1               17637647  17763184  2015-12-07 15:13:21
# 2                 664623  17763605  2015-12-07 15:35:01
#
#                         Email  \
# 0  myka.fernandes@hotmail.com
# 1        rebyslopes@gmail.com
# 2   murillomoraes08@gmail.com
#
#                                    FirstAccessedPage  \
# 0
# 1  https://www.passeidireto.com/arquivo/6452677/e...
# 2                      https://www.passeidireto.com/
#
#                    Fullname Gender        Id IsMobileRegister  \
# 0  MykaelaFernandes Correia  false  17763660             true
# 1               RebecaLopes  false  17763060            false
# 2      MurilloArcuri Moraes  false  17762776            false
#
#          LastLoginDate       RegisteredDate UploadCount
# 0  2015-12-07 15:37:51  2015-12-07 15:37:51           0
# 1  2015-12-07 15:06:48  2015-12-07 15:06:47           0
# 2  2015-12-07 15:22:28  2015-12-07 14:51:32           0

# %%
student_comment['Client_padron'] = '0'

for b in student_comment.itertuples():
    if b.Client.find("Android") != -1: 
        student_comment.Client_padron[b.Index] = 'Android' 
    if b.Client.find("iOS") !=-1: 
        student_comment.Client_padron[b.Index] = 'iOS'
    if b.Client.find("Mobile") !=-1: 
        student_comment.Client_padron[b.Index] = 'Mobile'
    if b.Client.find("PDJobs") !=-1: 
        student_comment.Client_padron[b.Index] = 'PDJobs'    
    if b.Client.find("Website") !=-1: 
        student_comment.Client_padron[b.Index] = 'Website'

# %%
student_comment = student_comment.drop('Client_padron',axis=1)

# %%
student_comment.groupby('Client_padron').count().Id
# Out:
# Client_padron
# Android     7537
# Mobile       962
# PDJobs        24
# Website    20070
# iOS         1407
# Name: Id, dtype: int64

# %%
# definindo o tamanho do gráfico
pylab.rcParams['figure.figsize'] = (5.0, 5.0)
fig, ax = plt.subplots()
#definindo o eixo y:
y_pos = np.arange(len(student_comment['Client_padron'].value_counts()))
#definindo o "tamanho" das barras:
values = student_comment['Client_padron'].value_counts()
# definindo os labels do eixo y:
segmentos = student_comment['Client_padron'].value_counts().index #é necessário colocar esse .index para que os segmentos sejam na mesma ordem 
#plotando o gráfico:
ax.barh(y_pos, values, align='center', color='gray')
ax.set_yticks(y_pos)
ax.set_yticklabels(segmentos)
ax.invert_yaxis() # para colocar em ordem decrescente
#ax.set_xlabel('') #descrição do eixo x
#ax.set_title('Meio de Acesso') #título
plt.show()

# %%
# Lendo os arquivos enviados:
with open(r'C:\Users\loren\Downloads\Passei Direto\student_download.json', encoding="utf8") as f:
    d = json.load(f)

student_download = json_normalize(d['student_download'])
student_download.head(3)
# Out:
#   Active   Client DownloadClient         DownloadDate DownloadFileID  \
# 0   true  Website                 2015-12-07 19:12:13        1561467
# 1   true  Website                 2015-12-07 19:09:54        1776861
# 2   true  Website                 2015-12-07 19:10:12        3616897
#
#   DownloadID                          Email  \
# 0   47839069      carolinabrovani@gmail.com
# 1   47838631  wesley10_henrique@hotmail.com
# 2   47838702             baluhh@hotmail.com
#
#                                    FirstAccessedPage     Fullname Gender  \
# 0  https://www.passeidireto.com/arquivo/1561467/m...    carolinab  false
# 1  https://www.passeidireto.com/arquivo/1776861/t...  Wesley Ruiz   true
# 2  https://www.passeidireto.com/arquivo/3616897/l...  LucasBrandt  false
#
#          Id IsMobileRegister        LastLoginDate       RegisteredDate  \
# 0  17769990            false  2015-12-07 19:10:41  2015-12-07 19:10:43
# 1  17769961            false  2015-12-07 19:08:39  2015-12-07 19:08:36
# 2  17769942            false  2015-12-07 19:07:41  2015-12-07 19:07:44
#
#   UploadCount
# 0           0
# 1           0
# 2           0

# %%
contagem = student_download[['Fullname','Id']].groupby(['Fullname'])['Id'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(20)

print (contagem)
# Out:
#                             Fullname  count
# 6310                          MARCOS    525
# 8307                     Renan Souza    338
# 1599               CarlosBruno Ramos    251
# 11053                             ka    223
# 3678        GildoCamargo de Almneida    176
# 810       AndréiaMarcionilio Caetano    169
# 9978                      Yuri Rocha    156
# 10380  cleytoneduardo costa ferreira    153
# 88                      Adriana Jean    147
# 5491                     Lais Castro    144
# 2905                     EstudantePD    136
# 3965                GustavoMagalhaes    121
# 8327                 Renata Barcelos    120
# 9068                          Talita    119
# 9892                  WilliamRibeiro    118
# 3292                      Filipebini    114
# 5663           Leonardo Albano Lugão    111
# 1970                              DB    107
# 3076        FaustoMarciano Morethson     96
# 3528               GabrielMendelwinc     96

# %%
contagem = student_download[['Id','Fullname']].groupby(['Id'])['Fullname'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(20)

print (contagem)
# Out:
#              Id  count
# 2024   17711766    512
# 3626   17719675    338
# 5883   17731369    251
# 11261  17758134    223
# 12119  17762431    176
# 3323   17718051    169
# 11608  17759804    156
# 9064   17747508    153
# 3753   17720349    147
# 9269   17748397    144
# 8803   17746207    121
# 7421   17739300    120
# 7555   17740012    118
# 7391   17739122    118
# 6935   17736938    114
# 11787  17760792    111
# 3485   17718914    107
# 6486   17734532     96
# 6611   17735206     96
# 1061   17707161     89

# %%
student_download[student_download['Id'] =='17711766']
#Tentando verificar de quem é o Id qu emais aparece na consulta acima. Somente para ter certeza que o Id é o Id do aluno
# Out:
#       Active   Client DownloadClient         DownloadDate DownloadFileID  \
# 42130   true  Website                 2015-12-03 19:23:13       17711362
# 42131   true  Website                 2015-12-03 18:33:59       17708123
# 42132   true  Website                 2015-12-03 19:23:06       17689341
# 42133   true  Website                 2015-12-03 19:18:07       17645600
# 42134   true  Website                 2015-12-03 19:22:19       17645600
# 42135   true  Website                 2015-12-03 19:23:09       17619051
# 42136   true  Website                 2015-12-03 19:23:13       17619048
# 42137   true  Website                 2015-12-03 19:23:15       17619040
# 42138   true  Website                 2015-12-03 19:23:20       17619027
# 3  https://www.passeidireto.com/arquivo/1811565/c...  Rute Chamié A. Souza
# 4  https://www.passeidireto.com/arquivo/17037685/...      Harila Eh Daniel
#
#      ...     IsMobileRegister        LastLoginDate       RegisteredDate  \
# 0    ...                false  2015-12-07 15:20:06  2015-12-07 14:14:23
# 1    ...                false  2015-12-07 14:12:05  2015-12-07 14:12:07
# 2    ...                false  2015-12-07 14:36:12  2015-12-07 14:36:11
# 3    ...                false  2015-12-07 16:45:04  2015-12-07 16:45:05
# 4    ...                false  2015-12-07 13:53:51  2015-12-07 13:53:53
#
#   StateId UniversityId                            UniversityName UploadCount  \
# 0     105       664565          Universidade Estácio de Sá - EAD           0
# 1      82       664623                Universidade Estácio de Sá           0
# 2      89       665123                      Faculdade Mineirense           0
# 3      83       663528  Universidade Federal Rural de Pernambuco           0
# 4      92       663509               Faculdade Unida de Campinas           0
#
#          cityName       stateName     Genero
# 0         Aracati           Ceara   Feminino
# 1  Rio de Janeiro  Rio de Janeiro   Feminino
# 2          Maceió         Alagoas  Masculino
# 3  Belo Horizonte    Minas Gerais   Feminino
# 4       Morrinhos           Goias   Feminino
#
# [5 rows x 21 columns]

# %%
result.groupby('Genero')['Qtd_Download'].describe()
# Out:
#            count      mean       std  min  25%  50%  75%   max
# Genero
# Feminino   117.0  2.846154  4.875370  1.0  1.0  1.0  3.0  39.0
# Masculino  128.0  2.453125  3.040046  1.0  1.0  1.0  3.0  22.0

# %%
dadosF=result[result[u'Genero']==u'Feminino'].Qtd_Download
dadosM=result[result[u'Genero']==u'Masculino'].Qtd_Download
# definindo o tamanho do gráfico
pylab.rcParams['figure.figsize'] = (5.0, 5.0)

# agrupa tabela
tabela_completa = (dadosM, dadosF)
 
# determina cor de cada estado no grafico
cores = ("blue", "red")
 
# cria um label para os grupos
Genero = ("Masc: Média=2.45 e Desv=3.04", "Fem: Média=2.85 e Desv=4.88")
 
# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, facecolor="1.0")
 
for data, color, group in zip(tabela_completa, cores, Genero):
    y = data
    x = range(len(data))
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)
 
    # titulo do grafico
   # plt.title('Dispersão Qtd. de Download')
 
    # insere legenda dos estados
    plt.legend(loc=1)
plt.show()

# %%
result.groupby('stateName')['Qtd_Download'].describe()
# Out:
#                      count      mean        std  min   25%  50%   75%   max
# stateName
# Acre                   1.0  1.000000        NaN  1.0  1.00  1.0  1.00   1.0
# Alagoas                5.0  6.000000   9.000000  1.0  1.00  3.0  3.00  22.0
# Amazonas               4.0  4.500000   5.196152  1.0  1.00  2.5  6.00  12.0
# Bahia                  6.0  1.166667   0.408248  1.0  1.00  1.0  1.00   2.0
# Ceara                 11.0  6.272727  11.181153  1.0  1.00  3.0  4.00  39.0
# Distrito Federal       8.0  1.750000   0.886405  1.0  1.00  1.5  2.25   3.0
# Espirito Santo         3.0  3.666667   4.618802  1.0  1.00  1.0  5.00   9.0
# Goias                  9.0  4.888889   5.035982  1.0  1.00  3.0  7.00  16.0
# Maranhão               3.0  2.333333   1.527525  1.0  1.50  2.0  3.00   4.0
# Mato Grosso            4.0  1.500000   1.000000  1.0  1.00  1.0  1.50   3.0
# Mato Grosso do Sul     1.0  1.000000        NaN  1.0  1.00  1.0  1.00   1.0
# Minas Gerais          33.0  2.424242   3.335700  1.0  1.00  1.0  2.00  18.0
# Paraná                15.0  2.733333   3.844600  1.0  1.00  1.0  2.00  15.0
# Paraíba                4.0  1.500000   1.000000  1.0  1.00  1.0  1.50   3.0
# Pará                   4.0  1.000000   0.000000  1.0  1.00  1.0  1.00   1.0
# Pernambuco             9.0  2.111111   1.452966  1.0  1.00  2.0  2.00   5.0
# Piauí                  2.0  1.500000   0.707107  1.0  1.25  1.5  1.75   2.0
# Rio Grande do Norte    6.0  2.166667   1.834848  1.0  1.00  1.0  3.25   5.0
# Rio Grande do Sul     14.0  1.571429   0.851631  1.0  1.00  1.0  2.00   3.0
# Rio de Janeiro        42.0  2.761905   3.992734  1.0  1.00  2.0  3.00  26.0
# Rondonia               1.0  5.000000        NaN  5.0  5.00  5.0  5.00   5.0
# Santa Catarina         6.0  2.333333   1.211060  1.0  1.25  2.5  3.00   4.0
# Sergipe                3.0  4.333333   4.041452  2.0  2.00  2.0  5.50   9.0
# São Paulo             51.0  2.019608   2.656992  1.0  1.00  1.0  2.00  15.0

# %%
with open(r'C:\Users\loren\Downloads\Passei Direto\student_evaluation.json', encoding="utf8") as f:
    d = json.load(f)

student_evaluation = json_normalize(d['student_evaluation'])
student_evaluation.head(3)
# Out:
#   Active     Client                         Email EvaluationClient  \
# 0   true     Mobile  wesleycostagomes13@gmail.com           Mobile
# 1   true  iOS | 9.1     netthynho_007@hotmail.com        iOS | 9.1
# 2   true    Website     havilo_weider@hotmail.com
#
#   EvaluationContentObjectID       EvaluationDate EvaluationID EvaluationValue  \
# 0                  17655774  2015-12-07 19:08:33      3578668            true
# 1                   1706563  2015-12-07 18:31:50      3578357           false
# 2                  17596604  2015-12-07 19:04:38      3578626            true
#
#                                    FirstAccessedPage  \
# 0
# 1
# 2  https://www.passeidireto.com/arquivo/2372371/a...
#
#                    Fullname Gender        Id IsMobileRegister  \
# 0              Wesley Costa   true  17769571             true
# 1          Netinho Oliveira   true  17769159             true
# 2  haviloweideraraujo lopes  false  17769065            false
#
#          LastLoginDate       RegisteredDate UploadCount
# 0  2015-12-07 18:46:49  2015-12-07 18:46:51           0
# 1  2015-12-07 18:27:51  2015-12-07 18:27:51           0
# 2  2015-12-07 18:23:49  2015-12-07 18:23:49           0

# %%
with open(r'C:\Users\loren\Downloads\Passei Direto\student_file_upload.json', encoding="utf8") as f:
    d = json.load(f)

student_file_upload = json_normalize(d['student_file_upload'])
student_file_upload.head(3)
# Out:
#   Active   Client                          Email FileContentObjectId  \
# 0   true  Website  marciopacheco.adm@hotmail.com             1504424
# 1   true  Website  marciopacheco.adm@hotmail.com             1504424
# 2   true  Website  marciopacheco.adm@hotmail.com             1504424
#
#   FileDownloadTotal FileEvaluationTotal                           FileFileUrl  \
# 0                 0                   0  508499d3-1ff6-4ad8-8abf-108f098090d6
# 1                 0                   0  29b9a95f-adfd-416d-b696-b0a7332691ab
# 2                 0                   0  ab294c4f-cba9-4765-9b18-b3d86aa762a8
#
#      FileID FilePreviewPageCount       FileUploadDate  \
# 0  17769351                    0  2015-12-07 18:36:41
# 1  17769346                    0  2015-12-07 18:36:30
# 2  17769342                    0  2015-12-07 18:36:18
#
#                FirstAccessedPage         Fullname Gender        Id  \
# 0  https://www.passeidireto.com/  MárcioAlexandre  false  17762846
# 1  https://www.passeidireto.com/  MárcioAlexandre  false  17762846
# 2  https://www.passeidireto.com/  MárcioAlexandre  false  17762846
#
#   IsMobileRegister        LastLoginDate       RegisteredDate UploadCount
# 0            false  2015-12-07 14:55:16  2015-12-07 14:55:15           0
# 1            false  2015-12-07 14:55:16  2015-12-07 14:55:15           0
# 2            false  2015-12-07 14:55:16  2015-12-07 14:55:15           0

# %%
with open(r'C:\Users\loren\Downloads\Passei Direto\student_loginlog_aggreagate.json', encoding="utf8") as f:
    d = json.load(f)

student_login = json_normalize(d['student_loginlog_aggreagate'])
student_login.head(3)
# Out:
#   Active   Client ClientLogin                             Email  \
# 0   true  Website                       daiane-juan@hotmail.com
# 1   true  Website                gabrielle_barreira@hotmail.com
# 2   true  Website              essentialpersonforlife@gmail.com
#
#                                    FirstAccessedPage                Fullname  \
# 0  https://www.passeidireto.com/arquivo/16619832/...      DaianeeJuan Avelar
# 1  https://www.passeidireto.com/arquivo/5035174/c...  GabrielleBarreira Goes
# 2  https://www.passeidireto.com/arquivo/3076452/s...    Sergen Hüseyin Özkan
#
#   Gender IP        Id IsMobileLogin IsMobileRegister        LastLoginDate  \
# 0  false     17769092         false            false  2015-12-07 18:24:35
# 1  false     17769091         false            false  2015-12-07 18:24:24
# 2   true     17769082         false            false  2015-12-07 18:24:12
#
#              LoginDate       RegisteredDate UploadCount
# 0  2015-12-07 18:24:35  2015-12-07 18:24:35           0
# 1  2015-12-07 18:24:24  2015-12-07 18:24:21           0
# 2  2015-12-07 18:24:12  2015-12-07 18:24:12           0

# %%
student_login.LastLoginDate.min()
# Out:
# '2015-12-07 16:18:02'

# %%
student_login.LastLoginDate.max()
# Out:
# '2015-12-07 18:24:35'

# %%
student_login.RegisteredDate.min()
# Out:
# '2015-12-07 16:18:02'

# %%
student_login.RegisteredDate.max()
# Out:
# '2015-12-07 18:24:35'

# %% [markdown]
# _________________________________________________________
#
# Com os resultados acima, é possível ver que o banco está com problemas nestes campos de data, pois por mais que esta base seja uma foto do dia 2015-12-07, é muito estranho o mínimo e o máximo tanto do último login quanto da data de registro serem exatamente iguais.
# _________________________________________________________

# %%
with open(r'C:\Users\loren\Downloads\Passei Direto\student_question.json', encoding="utf8") as f:
    d = json.load(f)

student_question = json_normalize(d['student_question'])
student_question.head(3)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-12-04a445608852> in <module>()
#       1 with open(r'C:\Users\loren\Downloads\Passei Direto\student_question.json', encoding="utf8") as f:
# ----> 2     d = json.load(f)
#       3
#       4 student_question = json_normalize(d['student_question'])
#       5 student_question.head(3)
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 599 column 405 (char 347744)
